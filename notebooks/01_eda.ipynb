# %% [markdown]
# # 01 EDA
# Exploratory analysis notebook.

# %%
import pandas as pd
df = pd.read_csv("data/insurance_data.csv")
print(df.shape, df.dtypes, df.isnull().sum())

# %%
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])
cat_cols = ['Province','VehicleType','Gender','CoverType','Make']
df[cat_cols] = df[cat_cols].astype('category')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])
#       2 cat_cols = ['Province','VehicleType','Gender','CoverType','Make']
#       3 df[cat_cols] = df[cat_cols].astype('category')
#
# NameError: name 'pd' is not defined

# %%
df['LossRatio'] = df['TotalClaims'] / df['TotalPremium'].replace(0, pd.NA)
df['Margin'] = df['TotalPremium'] - df['TotalClaims']
