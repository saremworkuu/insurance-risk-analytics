# %% [markdown]
# # 02 Hypothesis Testing
# Statistical testing notebook.

# %%
from scipy import stats

# H0: No risk difference by Province
# Segment: Gauteng (A) vs Western Cape (B)
group_a = df[df['Province'] == 'Gauteng']['has_claim']
group_b = df[df['Province'] == 'Western Cape']['has_claim']
chi2, p = stats.chi2_contingency(pd.crosstab(...))[0:2]
print(f"p = {p:.4f} → {'REJECT H0' if p < 0.05 else 'Fail to reject'}")
